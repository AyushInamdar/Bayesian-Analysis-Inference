# %% [markdown]
# ***Q1. Suppose you have a jar with 4 jelly beans: 2 are strawberry-flavored, 1 is blueberry-flavored, and 1 is cinnamon-flavored. You draw one jelly bean at random from the jar.***
#
#     a. What is the sample space for this experiment?
#
#     b. We define event A as the jelly bean drawn is strawberry-flavored and event B as The jelly bean drawn is not cinnamon-flavored. What are the probabilities of events A and B?
#
#     c. Are events A and B mutually exclusive? Why or why not?

# %% [markdown]
# a.
# The sample space is - {(strawberry),(strawberry),(blueberry),(cinnamon)}
#
# b.
# Event A - {(strawberry), (strawberry)}
# Event B - { (stawberry) , (strawberry) , (blueberry) }
# the probability of event A is 1/2 and that of event B is 3/4.
#
# c.
# The events A and B are not mutually exclusive, since it is possible for both events to take place together.

# %% [markdown]
# ***Q2. Previously, we defined a Python function P to compute the probability of an event using the naive definition of probability. Generalize that function to compute the probability of events when they are
#  not all equally likely. Use this new function to compute the probability of events A and B from the previous exercise.***
#
#  ***Hint: you can pass a third argument with the probability of each event.***

# %%
def P(S,A,probs):
  if ( set(A).issubset(set(S)) )
    return sum( probs[i] for i in A )
  else
    return 0

# here, probs is a dictionary containing the probabilities of each event occuring.
# for examples probs could be defined as probs = { 'strawberry' : 0.6, 'blueberry' : 0.2 ,'cinnamon' : 0.2}

# %% [markdown]
# ***Q3.  Use PreliZ to explore different parameters for the Gaussian distributions. Use the methods `plot_pdf`, `plot_cdf`, and `plot_interactive`. We discussed the probability mass/density functions and the cumulative density function. But there are other ways to represent functions like the percentile point function ppf. Using the `plot_ppf` method of PreliZ, plot the percentile point function for the BetaBinomial and Gaussian distributions. Can you explain how the ppf is related to the cdf and pmf/pdf?***

# %%
# !pip install pymc==5.8.0 arviz==0.16.1 bambi==0.13.0 pymc-bart==0.5.2 kulprit==0.0.1 preliz==0.3.6 nutpie==0.9.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import preliz as pz

# %%
# interactive normal
pz.Normal(0,1).plot_interactive()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='mu (-inf, inf)', max=10.0, min=-10.0, style=SliderSt…

# %%
pz.Normal(0,2).plot_pdf()
# Out:
# <Axes: >

# %%
pz.Normal(0,1).plot_cdf()
# Out:
# <Axes: >

# %%
pz.Normal(0,2).plot_cdf()
# Out:
# <Axes: >

# %%
# ppf of gaussian

pz.Normal(0,1).plot_ppf()
# Out:
# <Axes: >

# %%
pz.Normal(0,2).plot_ppf()
# Out:
# <Axes: >

# %%
# ppf of BetaBinomial
pz.BetaBinomial(10,10,5).plot_ppf()
# Out:
# <Axes: >

# %%
pz.BetaBinomial(15,10,5).plot_ppf()
# Out:
# <Axes: >

# %%
pz.BetaBinomial(10,15,5).plot_ppf()
# Out:
# <Axes: >

# %%
pz.BetaBinomial(10,10,10).plot_ppf()
# Out:
# <Axes: >

# %%
'''
Can you explain how the ppf is related to the cdf and pmf/pdf?

pmf(probability mass function) - given a discrete radnom variable ,
it is a function that gives the probability of each outcome, such as the tossing of a coin or rolling of a die

pdf(probability distribution function) - given a continuous random variable,
it gives the probability of the outcome being in a certain range, since the probability of a discrete value
is zero

cdf(cumulative distribution function)-gives the area under the graph for a pmf/pdf
gives the probability of getting an outcome lying in a certain range

ppf(percentile point function)
it tells us where a point would lie on a pdf/pmf based on the probability of
an outcome before it(ie based on cdf)
ppf is found by comuting the inverse of cdf
'''

# %% [markdown]
# Q4. Use PreliZ to compute the moments for the SkewNormal distribution for a different combination of parameters. Generate random samples of different sizes,
# like 10, 100, and 1,000, and see if you can recover the values of the first two moments (mean and variance) from the samples. Report your obervations.

# %%
pz.SkewNormal(0, 1, -5).plot_pdf(moments=["m", "d", "s", "k"])
# Out:
# <Axes: >

# %%
from scipy.stats import skewnorm

# %%
sizes = [10,100,1000,10000,100000]

#samples = np.random.skew(df=a, size=10)*d + m

for i in sizes:
  samples = skewnorm.rvs(-5, 0, 1, size=i)
  print(f"m = {samples.mean()}\nd={samples.std()}")
# Out:
# m = -0.5534423971966749
# d=0.26891053869724546
# m = -0.7122756560260762
# d=0.637641641533557
# m = -0.791805789344437
# d=0.6238796804988765
# m = -0.779768961293509
# d=0.6164476564398079
# m = -0.7820733923038293
# d=0.622083031384775

# %%
'''
we observe that as we increase the sample size,
the moments tend to the ones we arrived at earlier
'''
